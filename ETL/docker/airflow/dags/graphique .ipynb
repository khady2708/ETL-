# %%
import numpy as np
import matplotlib as plt
import sqlite3 as sq 
import pandas as pd

# %%
conn = sq.connect('/home/khady.thiam@Digital-Grenoble.local/Documents/ETL/docker/airflow/data/coins.db')
df = pd.read_sql_query('''SELECT * FROM price''', con=conn)

df
# Out:
#                    date nom_crypto currency  current_price       max_24h  \
# 0   2024-11-08 13:50:03    bitcoin      aed   2.790810e+05  2.823530e+05
# 1   2024-11-08 13:50:03    bitcoin      ars   7.554554e+07  7.639216e+07
# 2   2024-11-08 13:50:03    bitcoin      aud   1.149950e+05  1.150770e+05
# 3   2024-11-08 13:50:03    bitcoin      bch   2.039820e+02  2.051900e+02
# 4   2024-11-08 13:50:03    bitcoin      bdt   9.084282e+06  9.183885e+06
# ..                  ...        ...      ...            ...           ...
# 57  2024-11-08 13:50:18   ethereum      dot   6.829580e+02  7.026590e+02
# 58  2024-11-08 13:50:18   ethereum      eos   6.286000e+03  6.286000e+03
# 59  2024-11-08 13:50:18   ethereum      eth   1.000000e+00  1.000000e+00
# 60  2024-11-08 13:50:19   ethereum      eur   2.738530e+03  2.737320e+03
# 61  2024-11-08 13:50:19   ethereum      gbp   2.276210e+03  2.275200e+03
#
#          min_24h
# 0   2.742570e+05
# 1   7.423851e+07
# 2   1.119340e+05
# 3   1.972510e+02
# ...

# %%
df.plot()
df['']
# Out:
# <Axes: >

# %%
df['nom_crypto'].hist()
# Out:
# <Axes: >

# %%
df['current_price'].hist( bins=20)
# Out:
# <Axes: >

# %%
plot = df.plot.pie(y='current_price', figsize=(5, 5))
